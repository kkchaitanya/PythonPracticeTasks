# %%
l = [2,3,4,5,6]

# %%
l[0]
# Out:
# 2

# %%
l[4]
# Out:
# 6

# %%
for i in l :
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
s = "sudh"
for i in s :
    print(i)
# Out:
# s
# u
# d
# h

# %%
l
# Out:
# [2, 3, 4, 5, 6]

# %%
for i in l :
    print(i+1)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
l1 = []
for i in l :
    l1.append(i**2)

# %%
l1
# Out:
# [4, 9, 16, 25, 36]

# %%
t = (5,6,7,8,9)

# %%
for i in t:
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
d = {"name" :"sudh" ,
     "age":35 ,
     "no":2344,
     "subject" : ["python" , "gen ai " , "ops"]}

# %%
for i in d :
    print(d[i])
# Out:
# sudh
# 35
# 2344
# ['python', 'gen ai ', 'ops']

# %%
for i in d.keys():
    print(i)
# Out:
# name
# age
# no
# subject

# %%
for i in d.values():
    print(i)
# Out:
# sudh
# 35
# 2344
# ['python', 'gen ai ', 'ops']

# %%
for i in d.items():
    print(i)
# Out:
# ('name', 'sudh')
# ('age', 35)
# ('no', 2344)
# ('subject', ['python', 'gen ai ', 'ops'])

# %%
s = {3,4,5,6,6,7,78,8,8}

# %%
for i in s :
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 78

# %%
for i in l :
    print(i)
else:
    print("only execute when for will exhaust completle3y")
# Out:
# 2
# 3
# 4
# 5
# 6
# only execute when for will exhaust completle3y

# %%
for i in l:
    print(i)
    if i == 40:
        break
else:
    print("i will only execute when for will exahaust ")
# Out:
# 2
# 3
# 4
# 5
# 6
# i will only execute when for will exahaust

# %%
l= [10,20,30,40, 4,3,4,5,67,8,5,5,67,78,8,5,6,76]
target = 40
for i in l:
    if i == target:
        print("i found my value")
        break
else:
    print("not able to find")
# Out:
# i found my value
