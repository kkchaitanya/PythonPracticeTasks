# %%
s = "sudh"

# %%
s1 = "sudh"

# %%
s2 = "Sudh"

# %%
s2.lower()
# Out:
# 'sudh'

# %%
s2.upper()
# Out:
# 'SUDH'

# %%
s1.title()
# Out:
# 'Sudh'

# %%
s1
# Out:
# 'sudh'

# %%
s = "sudhanshu kumar"

# %%
s.title()
# Out:
# 'Sudhanshu Kumar'

# %%
s.capitalize()
# Out:
# 'Sudhanshu kumar'

# %%
s2
# Out:
# 'Sudh'

# %%
s2.swapcase()
# Out:
# 'sUDH'

# %%
s= "    sudh   "

# %%
s.strip()
# Out:
# 'sudh'

# %%
s.lstrip()
# Out:
# 'sudh   '

# %%
s.rstrip()
# Out:
# '    sudh'

# %%
s
# Out:
# '    sudh   '

# %%
s = "sudhanshu kumar"

# %%
s.count("s")
# Out:
# 2

# %%
s.index("udh")
# Out:
# 1

# %%
l = [3,4,5,6,"sudh"]

# %%
l.append("kumar")

# %%
l
# Out:
# [3, 4, 5, 6, 'sudh', 'kumar']

# %%
l.append([4,5,6,7])

# %%
l
# Out:
# [3, 4, 5, 6, 'sudh', 'kumar', [4, 5, 6, 7]]

# %%
l.extend("sudh")

# %%
l
# Out:
# [3, 4, 5, 6, 'sudh', 'kumar', [4, 5, 6, 7], 's', 'u', 'd', 'h']

# %%
l.extend(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l.extend(45)
#
# TypeError: 'int' object is not iterable

# %%
l.extend([3,4,5,6])

# %%
l
# Out:
# [3, 4, 5, 6, 'sudh', 'kumar', [4, 5, 6, 7], 's', 'u', 'd', 'h', 3, 4, 5, 6]

# %%
l.insert(3,"euron")

# %%
l
# Out:
# [3,
#  4,
#  5,
#  'euron',
#  6,
#  'sudh',
#  'kumar',
#  [4, 5, 6, 7],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  6]

# %%
l
# Out:
# [3,
#  4,
#  5,
#  'euron',
#  6,
#  'sudh',
#  'kumar',
#  [4, 5, 6, 7],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  6]

# %%
l.remove(6)

# %%
l
# Out:
# [3,
#  4,
#  5,
#  'euron',
#  'sudh',
#  'kumar',
#  [4, 5, 6, 7],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  6]

# %%
l.pop()
# Out:
# 6

# %%
l.pop()
# Out:
# 5

# %%
l.pop()
# Out:
# 4

# %%
l.pop()
# Out:
# 3

# %%
l
# Out:
# [3, 4, 5, 'euron', 'sudh', 'kumar', [4, 5, 6, 7], 's', 'u', 'd', 'h']

# %%
l.pop()
# Out:
# 'h'

# %%
l
# Out:
# [3, 4, 5, 'euron', 'sudh', 'kumar', [4, 5, 6, 7], 's', 'u', 'd']

# %%
l.pop(3)
# Out:
# 'euron'

# %%
l
# Out:
# [3, 4, 5, 'sudh', 'kumar', [4, 5, 6, 7], 's', 'u', 'd']

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l = [4,5,6,7,78,8,3,3,4,56]

# %%
l.count(4)
# Out:
# 2

# %%
l.index(4)
# Out:
# 0

# %%
l.index(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 l.index(234)
#
# ValueError: 234 is not in list

# %%
l
# Out:
# [4, 5, 6, 7, 78, 8, 3, 3, 4, 56]

# %%
l[::-1]
# Out:
# [56, 4, 3, 3, 8, 78, 7, 6, 5, 4]

# %%
l
# Out:
# [4, 5, 6, 7, 78, 8, 3, 3, 4, 56]

# %%
l.reverse()

# %%
l
# Out:
# [56, 4, 3, 3, 8, 78, 7, 6, 5, 4]

# %%
t = (4,5,6,78,8)

# %%
t.count(4)
# Out:
# 1

# %%
t.index(78)
# Out:
# 3

# %%
l = [4,5,6,7,8]

# %%
l1 = l

# %%
l2 = l.copy()

# %%
l[0] = "sudh"

# %%
l
# Out:
# ['sudh', 5, 6, 7, 8]

# %%
l1
# Out:
# ['sudh', 5, 6, 7, 8]

# %%
l2
# Out:
# [4, 5, 6, 7, 8]

# %%
l2[0] = "sdfsdsdfsf"

# %%
l2
# Out:
# ['sdfsdsdfsf', 5, 6, 7, 8]

# %%
l
# Out:
# ['sudh', 5, 6, 7, 8]

# %%
id(l)
# Out:
# 2746484600768

# %%
id(l1)
# Out:
# 2746484600768

# %%
id(l2)
# Out:
# 2746484521856

# %%
d = {"name" : "sudh" ,
     "no" : 2343242,
     "mail" :"sudhanshu@euron.one",
     "topics" : ["xyz" , "abc"]}

# %%
d
# Out:
# {'name': 'sudh',
#  'no': 2343242,
#  'mail': 'sudhanshu@euron.one',
#  'topics': ['xyz', 'abc']}

# %%
list(d.keys())
# Out:
# ['name', 'no', 'mail', 'topics']

# %%
d.values()
# Out:
# dict_values(['sudh', 2343242, 'sudhanshu@euron.one', ['xyz', 'abc']])

# %%
d.items()
# Out:
# dict_items([('name', 'sudh'), ('no', 2343242), ('mail', 'sudhanshu@euron.one'), ('topics', ['xyz', 'abc'])])

# %%
d.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 d.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d.pop("no")
# Out:
# 2343242

# %%
d
# Out:
# {'name': 'sudh', 'mail': 'sudhanshu@euron.one', 'topics': ['xyz', 'abc']}

# %%
d.popitem()
# Out:
# ('topics', ['xyz', 'abc'])

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
s = {4,4,54,6,67,7,4,5,6,7,8,4,54,56,76}

# %%
s.add("sudh")

# %%
s
# Out:
# {4, 5, 54, 56, 6, 67, 7, 76, 8, 'sudh'}

# %%
s.update([3,4,5,6])

# %%
s
# Out:
# {3, 4, 5, 54, 56, 6, 67, 7, 76, 8, 'sudh'}

# %%
s.remove(3)

# %%
s
# Out:
# {4, 5, 54, 56, 6, 67, 7, 76, 8, 'sudh'}

# %%
s.pop()
# Out:
# 67

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
d
# Out:
# {}

# %%
d["test"] = "fsdsf"

# %%
d
# Out:
# {'test': 'fsdsf'}
