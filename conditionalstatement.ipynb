# %%
age = 16

if age >=18 :
    print("yes i am eligible for voting")

# %%
age >=18
# Out:
# False

# %%
age = 16

if age >=18 :
    print("yes i am eligible for voting")
else:
    print("i am not eligible")
# Out:
# i am not eligible

# %%
num = int(input("enter the number"))

if num > 0 :
    print("number is positive")
elif num <0 :
    print("number is negative")
else:
    print("the nuymber is zero")
# Out:
# the nuymber is zero

# %%
num = int(input("enter the number"))

if num % 2 == 0 :
    print("the entered number is even")
else :
    print("the entered number is odd")
# Out:
# the entered number is odd

# %%
a = int(input("enter the value of a"))
b = int(input("enter the valur of b "))
c = int(input("enter the value of c"))

if a>=b and a >=c:
    print("a is the largest number " , a)
elif b>=a and b>=c:
    print("b is the largest number",b)
else:
    print("c is the largest" , c)
# Out:
# c is the largest 10

# %%
age= 2

if age>=18:
    if age>=60:
        print("sennior person")
    else:
        print("adult")
else:
    print("minor")
# Out:
# minor
