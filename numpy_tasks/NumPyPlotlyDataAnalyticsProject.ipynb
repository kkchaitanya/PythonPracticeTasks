# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
months =  np.array(["Jan", "Feb", "Mar", "Apr", "May", "Jun","Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
revenue = np.random.randint(500000, 2000000, 12) # Revenue in ₹
orders = np.random.randint(1000, 10000, 12) # Number of orders
customers = np.random.randint(800, 8000, 12) # Number of customers
expenses = np.random.randint(300000, 1200000, 12) # Expenses in ₹

# %%
print(months)
print(revenue)
print(orders)
print(customers)
print(expenses)
# Out:
# ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']
# [1706283  731599 1508941  716241 1758324 1087721 1487667 1802067  546029
#   928043 1916150  969375]
# [1091 7232 8249 7034 6132 8533 6220 9151 7762 6226 3191 1639]
# [3473 4288 2038 3060 3415 1372 3144 5094 1145 7649 7052 7805]
# [ 709758 1156640  573004  412541  459300 1060874  538849  463432  586340
#   968504  499021  460539]

# %%
revenue_df= pd.DataFrame({
            "Month": months,
            "Orders": orders,
            "Revenue": revenue,
            "Customers":customers,
            "Expenses":expenses
            })

# %%
print(revenue_df)
# Out:
#    Month  Orders  Revenue  Customers  Expenses
# 0    Jan    1091  1706283       3473    709758
# 1    Feb    7232   731599       4288   1156640
# 2    Mar    8249  1508941       2038    573004
# 3    Apr    7034   716241       3060    412541
# 4    May    6132  1758324       3415    459300
# 5    Jun    8533  1087721       1372   1060874
# 6    Jul    6220  1487667       3144    538849
# 7    Aug    9151  1802067       5094    463432
# 8    Sep    7762   546029       1145    586340
# 9    Oct    6226   928043       7649    968504
# 10   Nov    3191  1916150       7052    499021
# 11   Dec    1639   969375       7805    460539

# %%
### Calculate total annual revenue.###
print("total annual revenue",revenue_df["Revenue"].sum())
# Out:
# total annual revenue 15158440

# %%
### Calculate average monthly revenue. ###
print("average monthly revenue.",revenue_df["Revenue"].mean())
# Out:
# average monthly revenue. 1263203.3333333333

# %%
### Find the best-performing month. ###
print("best-performing month")
# print(revenue_df[revenue_df["Revenue"]==revenue_df["Revenue"].max()]["Month"])
print(revenue_df.loc[revenue_df["Revenue"].idxmax(), "Month"])
# Out:
# best-performing month
# Nov

# %%
### Find the lowest-performing month. ###
print("Find the lowest-performing month.")
print(revenue_df.loc[revenue_df["Revenue"].idxmin(), "Month"])
# Out:
# Find the lowest-performing month.
# Sep

# %%
## Calculate month-to-month revenue differences. ##
revenue_df["Revenue_Difference"] = revenue_df["Revenue"].diff()
print(revenue_df)

## Create a bar chart showing monthly orders. ##
# Out:
#    Month  Orders  Revenue  Customers  Expenses  Revenue_Difference
# 0    Jan    1091  1706283       3473    709758                 NaN
# 1    Feb    7232   731599       4288   1156640           -974684.0
# 2    Mar    8249  1508941       2038    573004            777342.0
# 3    Apr    7034   716241       3060    412541           -792700.0
# 4    May    6132  1758324       3415    459300           1042083.0
# 5    Jun    8533  1087721       1372   1060874           -670603.0
# 6    Jul    6220  1487667       3144    538849            399946.0
# 7    Aug    9151  1802067       5094    463432            314400.0
# 8    Sep    7762   546029       1145    586340          -1256038.0
# 9    Oct    6226   928043       7649    968504            382014.0
# 10   Nov    3191  1916150       7052    499021            988107.0
# 11   Dec    1639   969375       7805    460539           -946775.0

# %%
# %pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (5.11.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.19.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Create a line chart showing revenue trends. ##
line_chart = px.line(
                revenue_df,
                x="Month",
                y="Revenue",
                title="Monthly Revenue Trend",
                markers=True)
line_chart.show()

# %%
## Create a bar chart showing monthly orders
bar_chart = px.bar(revenue_df,
                   x="Month",
                   y="Orders",
                   title="monthly orders"
                   )
bar_chart.show()

# %%
fig = px.line(
    revenue_df,
    x="Month",
    y=["Revenue", "Expenses"],
    markers=True,
    title="Monthly Revenue vs Expenses"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Amount",
    legend_title="Metrics",
    template="plotly_white"
)

fig.show()

# %%
import plotly.express as px

fig = px.bar(
    revenue_df,
    x="Month",
    y=["Revenue", "Expenses"],
    barmode="group",
    title="Monthly Revenue vs Expenses",
    labels={
        "value": "Amount",
        "variable": "Metric"
    }
)

fig.show()
