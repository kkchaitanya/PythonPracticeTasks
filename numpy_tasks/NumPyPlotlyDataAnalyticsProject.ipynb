# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
months =  np.array(["Jan", "Feb", "Mar", "Apr", "May", "Jun","Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
revenue = np.random.randint(500000, 2000000, 12) # Revenue in ₹
orders = np.random.randint(1000, 10000, 12) # Number of orders
customers = np.random.randint(800, 8000, 12) # Number of customers
expenses = np.random.randint(300000, 1200000, 12) # Expenses in ₹

# %%
print(months)
print(revenue)
print(orders)
print(customers)
print(expenses)
# Out:
# ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']
# [ 639793 1298308  927544  963839  858261 1029262 1026475 1057972 1468960
#  1050352 1034143 1021397]
# [2632 6920 1034 9790 1669 7500 4670 8378 9862 8952 7793 8648]
# [7261 5517 2106 7250 1710 4162 4278  821  811 6230 4834 3099]
# [1169206  826338 1170926  938182  991574  540642  856512 1105297  396917
#   963985  400271 1085873]

# %%
revenue_df= pd.DataFrame({
            "Month": months,
            "Orders": orders,
            "Revenue": revenue,
            "Customers":customers,
            "Expenses":expenses
            })

# %%
print(revenue_df)
# Out:
#    Month  Orders  Revenue  Customers  Expenses
# 0    Jan    2632   639793       7261   1169206
# 1    Feb    6920  1298308       5517    826338
# 2    Mar    1034   927544       2106   1170926
# 3    Apr    9790   963839       7250    938182
# 4    May    1669   858261       1710    991574
# 5    Jun    7500  1029262       4162    540642
# 6    Jul    4670  1026475       4278    856512
# 7    Aug    8378  1057972        821   1105297
# 8    Sep    9862  1468960        811    396917
# 9    Oct    8952  1050352       6230    963985
# 10   Nov    7793  1034143       4834    400271
# 11   Dec    8648  1021397       3099   1085873

# %%
### Calculate total annual revenue.###
print("total annual revenue",revenue_df["Revenue"].sum())
# Out:
# total annual revenue 12376306

# %%
### Calculate average monthly revenue. ###
print("average monthly revenue.",revenue_df["Revenue"].mean())
# Out:
# average monthly revenue. 1031358.8333333334

# %%
### Find the best-performing month. ###
print("best-performing month")
# print(revenue_df[revenue_df["Revenue"]==revenue_df["Revenue"].max()]["Month"])
print(revenue_df.loc[revenue_df["Revenue"].idxmax(), "Month"])
# Out:
# best-performing month
# Sep

# %%
### Find the lowest-performing month. ###
print("Find the lowest-performing month.")
print(revenue_df.loc[revenue_df["Revenue"].idxmin(), "Month"])
# Out:
# Find the lowest-performing month.
# Jan

# %%
## Calculate month-to-month revenue differences. ##
revenue_df["Revenue_Difference"] = revenue_df["Revenue"].diff()
print(revenue_df)

## Create a bar chart showing monthly orders. ##
# Out:
#    Month  Orders  Revenue  Customers  Expenses  Revenue_Difference
# 0    Jan    2632   639793       7261   1169206                 NaN
# 1    Feb    6920  1298308       5517    826338            658515.0
# 2    Mar    1034   927544       2106   1170926           -370764.0
# 3    Apr    9790   963839       7250    938182             36295.0
# 4    May    1669   858261       1710    991574           -105578.0
# 5    Jun    7500  1029262       4162    540642            171001.0
# 6    Jul    4670  1026475       4278    856512             -2787.0
# 7    Aug    8378  1057972        821   1105297             31497.0
# 8    Sep    9862  1468960        811    396917            410988.0
# 9    Oct    8952  1050352       6230    963985           -418608.0
# 10   Nov    7793  1034143       4834    400271            -16209.0
# 11   Dec    8648  1021397       3099   1085873            -12746.0

# %%
# %pip install --upgrade nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (5.11.1)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbformat) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbformat) (5.15.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=2.6->nbformat) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\KKOMARAV\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\KKOMARAV\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
## Create a line chart showing revenue trends. ##
line_chart = px.line(
                revenue_df,
                x="Month",
                y="Revenue",
                title="Monthly Revenue Trend",
                markers=True)
line_chart.show()

# %%
## Create a bar chart showing monthly orders
bar_chart = px.bar(revenue_df,
                   x="Month",
                   y="Orders",
                   title="monthly orders"
                   )
bar_chart.show()

# %%
fig = px.line(
    revenue_df,
    x="Month",
    y=["Revenue", "Expenses"],
    markers=True,
    title="Monthly Revenue vs Expenses"
)

fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Amount",
    legend_title="Metrics",
    template="plotly_white"
)

fig.show()

# %%
import plotly.express as px

fig = px.bar(
    revenue_df,
    x="Month",
    y=["Revenue", "Expenses"],
    barmode="group",
    title="Monthly Revenue vs Expenses",
    labels={
        "value": "Amount",
        "variable": "Metric"
    }
)

fig.show()

# %%
## Create customer-growth visualization.##
line_chart = px.line(
                revenue_df,
                x="Month",
                y="Customers",
                title="Customers growth",
                markers=True)
line_chart.show()

# %%
# Calculate profit
# Profit = Revenue - Expenses
# and visualize monthly profit.

revenue_df["Profit"]= revenue_df["Revenue"]-revenue_df["Expenses"]
# print(revenue_df)
line_chart = px.line(
                revenue_df,
                x="Month",
                y="Profit",
                title="Profit profit",
                markers=True)
line_chart.show(renderer="browser")
# Out:
#    Month  Orders  Revenue  Customers  Expenses  Revenue_Difference   Profit
# 0    Jan    2632   639793       7261   1169206                 NaN  -529413
# 1    Feb    6920  1298308       5517    826338            658515.0   471970
# 2    Mar    1034   927544       2106   1170926           -370764.0  -243382
# 3    Apr    9790   963839       7250    938182             36295.0    25657
# 4    May    1669   858261       1710    991574           -105578.0  -133313
# 5    Jun    7500  1029262       4162    540642            171001.0   488620
# 6    Jul    4670  1026475       4278    856512             -2787.0   169963
# 7    Aug    8378  1057972        821   1105297             31497.0   -47325
# 8    Sep    9862  1468960        811    396917            410988.0  1072043
# 9    Oct    8952  1050352       6230    963985           -418608.0    86367
# 10   Nov    7793  1034143       4834    400271            -16209.0   633872
# 11   Dec    8648  1021397       3099   1085873            -12746.0   -64476

# %%
bar_chart = px.bar(
                revenue_df,
                x="Month",
                y="Profit",
                title="Profit profit",
               )
bar_chart.show(renderer="browser")

# %%
import plotly.graph_objects as go
fig = go.Figure()

# Revenue
fig.add_trace(
    go.Scatter(
        x=revenue_df["Month"],
        y=revenue_df["Revenue"],
        mode="lines+markers",
        name="Revenue",
        line=dict(color="blue", width=3)
    )
)

# Expenses
fig.add_trace(
    go.Scatter(
        x=revenue_df["Month"],
        y=revenue_df["Expenses"],
        mode="lines+markers",
        name="Expenses",
        line=dict(color="red", width=3)
    )
)

# Profit
fig.add_trace(
    go.Bar(
        x=revenue_df["Month"],
        y=revenue_df["Profit"],
        name="Profit",
        marker_color="green"
    )
)

fig.update_layout(
    title="E-Commerce Performance Dashboard",
    xaxis_title="Month",
    yaxis_title="Amount (₹)",
    template="plotly_white",
    hovermode="x unified"
)

fig.show(renderer="browser")
